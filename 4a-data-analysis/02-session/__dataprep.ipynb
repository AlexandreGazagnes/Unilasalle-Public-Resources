# %%
ls
# Out:
# 01-notebook.ipynb  alim.csv  chiken.csv  __dataprep.ipynb  DEPRECATED/  pop.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("alim.csv")

# %%
df
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 0               5511                                         Production
# 1               5611                            Importations - Quantité
# 2               5072                                 Variation de stock
# 3               5911                            Exportations - Quantité
# 4               5301                           Disponibilité intérieure
# ...              ...                                                ...
# 176595          5142                                         Nourriture
# 176596           645  Disponibilité alimentaire en quantité (kg/pers...
# 176597           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176598           674  Disponibilité de protéines en quantité (g/pers...
# 176599           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  Blé et produits        2017   2017  Milliers de tonnes
# 1               2511  Blé et produits        2017   2017  Milliers de tonnes
# 2               2511  Blé et produits        2017   2017  Milliers de tonnes
# 3               2511  Blé et produits        2017   2017  Milliers de tonnes
# 4               2511  Blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     Miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     Miscellanees        2017   2017                  kg
# 176597          2899     Miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     Miscellanees        2017   2017     g/personne/jour
# 176599          2899     Miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %%
df.Produit
# Out:
# 0         Blé et produits
# 1         Blé et produits
# 2         Blé et produits
# 3         Blé et produits
# 4         Blé et produits
#                ...
# 176595       Miscellanees
# 176596       Miscellanees
# 176597       Miscellanees
# 176598       Miscellanees
# 176599       Miscellanees
# Name: Produit, Length: 176600, dtype: object

# %%
df.Produit.unique()
# Out:
# array(['Blé et produits', 'Riz et produits', 'Orge et produits',
#        'Maïs et produits', 'Seigle et produits', 'Avoine',
#        'Millet et produits', 'Sorgho et produits', 'Céréales, Autres',
#        'Pommes de Terre et produits', 'Ignames', 'Racines nda',
#        'Sucre, canne', 'Sucre, betterave', 'Sucre Eq Brut',
#        'Edulcorants Autres', 'Miel', 'Haricots', 'Pois',
#        'Légumineuses Autres et produits', 'Noix et produits', 'Soja',
#        'Arachides Decortiquees', 'Graines de tournesol',
#        'Graines Colza/Moutarde', 'Graines de coton', 'Coco (Incl Coprah)',
#        'Sésame', 'Olives', 'Plantes Oleiferes, Autre', 'Huile de Soja',
#        "Huile d'Arachide", 'Huile de Tournesol',
#        'Huile de Colza&Moutarde', 'Huile Graines de Coton',
#        'Huile de Palmistes', 'Huile de Palme', 'Huile de Coco',
#        'Huile de Sésame', "Huile d'Olive", 'Huile de Son de Riz',
#        'Huile de Germe de Maïs', 'Huil Plantes Oleif Autr',
#        'Tomates et produits', 'Oignons', 'Légumes, Autres',
#        'Oranges, Mandarines', 'Citrons & Limes et produits',
#        'Pamplemousse et produits', 'Agrumes, Autres', 'Bananes',
#        'Pommes et produits', 'Ananas et produits', 'Dattes', 'Raisin',
#        'Fruits, Autres', 'Café et produits', 'Feve de Cacao et produits',
#        'Thé', 'Poivre', 'Piments', 'Girofles', 'Épices, Autres', 'Vin',
#        'Bière', 'Boissons Fermentés', 'Boissons Alcooliques',
#        'Alcool, non Comestible', 'Viande de Bovins',
#        "Viande d'Ovins/Caprins", 'Viande de Suides',
#        'Viande de Volailles', 'Viande, Autre', 'Abats Comestible',
#        'Beurre, Ghee', 'Crème', 'Graisses Animales Crue', 'Oeufs',
#        'Lait - Excl Beurre', 'Poissons Eau Douce',
#        'Aliments pour enfants', 'Miscellanees', 'Manioc et produits',
#        'Patates douces', 'Palmistes', 'Bananes plantains',
#        'Huiles de Poissons', 'Huiles de Foie de Poisso', 'Perciform',
#        'Poissons Pelagiques', 'Poissons Marins, Autres', 'Crustacés',
#        'Cephalopodes', 'Mollusques, Autres', 'Animaux Aquatiques Autre',
#        'Plantes Aquatiques', 'Sucre non centrifugé',
#        'Viande de Anim Aquatiq'], dtype=object)

# %%
df.Produit = df.Produit.str.lower()
df
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 0               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4               FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176595          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176596          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176597          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176598          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176599          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 0               5511                                         Production
# 1               5611                            Importations - Quantité
# 2               5072                                 Variation de stock
# 3               5911                            Exportations - Quantité
# 4               5301                           Disponibilité intérieure
# ...              ...                                                ...
# 176595          5142                                         Nourriture
# 176596           645  Disponibilité alimentaire en quantité (kg/pers...
# 176597           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176598           674  Disponibilité de protéines en quantité (g/pers...
# 176599           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit          Produit  Code année  Année               Unité  \
# 0               2511  blé et produits        2017   2017  Milliers de tonnes
# 1               2511  blé et produits        2017   2017  Milliers de tonnes
# 2               2511  blé et produits        2017   2017  Milliers de tonnes
# 3               2511  blé et produits        2017   2017  Milliers de tonnes
# 4               2511  blé et produits        2017   2017  Milliers de tonnes
# ...              ...              ...         ...    ...                 ...
# 176595          2899     miscellanees        2017   2017  Milliers de tonnes
# 176596          2899     miscellanees        2017   2017                  kg
# 176597          2899     miscellanees        2017   2017  Kcal/personne/jour
# 176598          2899     miscellanees        2017   2017     g/personne/jour
# 176599          2899     miscellanees        2017   2017     g/personne/jour
#
#          Valeur Symbole Description du Symbole
# 0       4281.00       S  Données standardisées
# 1       2302.00       S  Données standardisées
# 2       -119.00       S  Données standardisées
# 3          0.00       S  Données standardisées
# 4       6701.00       S  Données standardisées
# ...         ...     ...                    ...
# 176595    19.00       S  Données standardisées
# 176596     1.33      Fc        Donnée calculée
# 176597     1.00      Fc        Donnée calculée
# 176598     0.04      Fc        Donnée calculée
# 176599     0.02      Fc        Donnée calculée
#
# [176600 rows x 14 columns]

# %%
produits = list(df.Produit.unique())

# %%
produits = [i.lower() for i in produits]    
produits
# Out:
# ['blé et produits',
#  'riz et produits',
#  'orge et produits',
#  'maïs et produits',
#  'seigle et produits',
#  'avoine',
#  'millet et produits',
#  'sorgho et produits',
#  'céréales, autres',
#  'pommes de terre et produits',
#  'ignames',
#  'racines nda',
#  'sucre, canne',
#  'sucre, betterave',
#  'sucre eq brut',
#  'edulcorants autres',
#  'miel',
#  'haricots',
#  'pois',
#  'légumineuses autres et produits',
#  'noix et produits',
#  'soja',
#  'arachides decortiquees',
#  'graines de tournesol',
#  'graines colza/moutarde',
#  'graines de coton',
#  'coco (incl coprah)',
#  'sésame',
#  'olives',
#  'plantes oleiferes, autre',
#  'huile de soja',
#  "huile d'arachide",
#  'huile de tournesol',
#  'huile de colza&moutarde',
#  'huile graines de coton',
#  'huile de palmistes',
#  'huile de palme',
#  'huile de coco',
#  'huile de sésame',
#  "huile d'olive",
#  'huile de son de riz',
#  'huile de germe de maïs',
#  'huil plantes oleif autr',
#  'tomates et produits',
#  'oignons',
#  'légumes, autres',
#  'oranges, mandarines',
#  'citrons & limes et produits',
#  'pamplemousse et produits',
#  'agrumes, autres',
#  'bananes',
#  'pommes et produits',
#  'ananas et produits',
#  'dattes',
#  'raisin',
#  'fruits, autres',
#  'café et produits',
#  'feve de cacao et produits',
#  'thé',
#  'poivre',
#  'piments',
#  'girofles',
#  'épices, autres',
#  'vin',
#  'bière',
#  'boissons fermentés',
#  'boissons alcooliques',
#  'alcool, non comestible',
#  'viande de bovins',
#  "viande d'ovins/caprins",
#  'viande de suides',
#  'viande de volailles',
#  'viande, autre',
#  'abats comestible',
#  'beurre, ghee',
#  'crème',
#  'graisses animales crue',
#  'oeufs',
#  'lait - excl beurre',
#  'poissons eau douce',
#  'aliments pour enfants',
#  'miscellanees',
#  'manioc et produits',
#  'patates douces',
#  'palmistes',
#  'bananes plantains',
#  'huiles de poissons',
#  'huiles de foie de poisso',
#  'perciform',
#  'poissons pelagiques',
#  'poissons marins, autres',
#  'crustacés',
#  'cephalopodes',
#  'mollusques, autres',
#  'animaux aquatiques autre',
#  'plantes aquatiques',
#  'sucre non centrifugé',
#  'viande de anim aquatiq']

# %%
[i for i in produits if "chiken" in i]
# Out:
# []

# %%
[i for i in produits if "poulet" in i]
# Out:
# []

# %%
[i for i in produits if "volai" in i]
# Out:
# ['viande de volailles']

# %%
df = df.loc[df.Produit == "viande de volailles"]
df
# Out:
#        Code Domaine                      Domaine  Code zone         Zone  \
# 651             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 652             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 653             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 654             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 655             FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# ...             ...                          ...        ...          ...
# 176396          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176397          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176398          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176399          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
# 176400          FBS  Nouveaux Bilans Alimentaire        181     Zimbabwe
#
#         Code Élément                                            Élément  \
# 651             5511                                         Production
# 652             5611                            Importations - Quantité
# 653             5072                                 Variation de stock
# 654             5301                           Disponibilité intérieure
# 655             5123                                             Pertes
# ...              ...                                                ...
# 176396          5142                                         Nourriture
# 176397           645  Disponibilité alimentaire en quantité (kg/pers...
# 176398           664     Disponibilité alimentaire (Kcal/personne/jour)
# 176399           674  Disponibilité de protéines en quantité (g/pers...
# 176400           684  Disponibilité de matière grasse en quantité (g...
#
#         Code Produit              Produit  Code année  Année  \
# 651             2734  viande de volailles        2017   2017
# 652             2734  viande de volailles        2017   2017
# 653             2734  viande de volailles        2017   2017
# 654             2734  viande de volailles        2017   2017
# 655             2734  viande de volailles        2017   2017
# ...              ...                  ...         ...    ...
# 176396          2734  viande de volailles        2017   2017
# 176397          2734  viande de volailles        2017   2017
# 176398          2734  viande de volailles        2017   2017
# 176399          2734  viande de volailles        2017   2017
# 176400          2734  viande de volailles        2017   2017
#
#                      Unité  Valeur Symbole Description du Symbole
# 651     Milliers de tonnes   28.00       S  Données standardisées
# 652     Milliers de tonnes   29.00       S  Données standardisées
# 653     Milliers de tonnes    0.00       S  Données standardisées
# 654     Milliers de tonnes   57.00       S  Données standardisées
# 655     Milliers de tonnes    2.00       S  Données standardisées
# ...                    ...     ...     ...                    ...
# 176396  Milliers de tonnes   67.00       S  Données standardisées
# 176397                  kg    4.68      Fc        Donnée calculée
# 176398  Kcal/personne/jour   16.00      Fc        Donnée calculée
# 176399     g/personne/jour    1.59      Fc        Donnée calculée
# 176400     g/personne/jour    0.99      Fc        Donnée calculée
#
# [2061 rows x 14 columns]

# %%
df.nunique()
# Out:
# Code Domaine                1
# Domaine                     1
# Code zone                 172
# Zone                      172
# Code Élément               17
# Élément                    17
# Code Produit                1
# Produit                     1
# Code année                  1
# Année                       1
# Unité                       4
# Valeur                    843
# Symbole                     2
# Description du Symbole      2
# dtype: int64

# %%
tmp = df.nunique()
tmp = tmp[tmp > 1]
tmp
# Out:
# Code zone                 172
# Zone                      172
# Code Élément               17
# Élément                    17
# Unité                       4
# Valeur                    843
# Symbole                     2
# Description du Symbole      2
# dtype: int64

# %%
tmp.index
# Out:
# Index(['Code zone', 'Zone', 'Code Élément', 'Élément', 'Unité', 'Valeur',
#        'Symbole', 'Description du Symbole'],
#       dtype='object')

# %%
df = df.loc[:, tmp.index]
df
# Out:
#         Code zone         Zone  Code Élément  \
# 651             2  Afghanistan          5511
# 652             2  Afghanistan          5611
# 653             2  Afghanistan          5072
# 654             2  Afghanistan          5301
# 655             2  Afghanistan          5123
# ...           ...          ...           ...
# 176396        181     Zimbabwe          5142
# 176397        181     Zimbabwe           645
# 176398        181     Zimbabwe           664
# 176399        181     Zimbabwe           674
# 176400        181     Zimbabwe           684
#
#                                                   Élément               Unité  \
# 651                                            Production  Milliers de tonnes
# 652                               Importations - Quantité  Milliers de tonnes
# 653                                    Variation de stock  Milliers de tonnes
# 654                              Disponibilité intérieure  Milliers de tonnes
# 655                                                Pertes  Milliers de tonnes
# ...                                                   ...                 ...
# 176396                                         Nourriture  Milliers de tonnes
# 176397  Disponibilité alimentaire en quantité (kg/pers...                  kg
# 176398     Disponibilité alimentaire (Kcal/personne/jour)  Kcal/personne/jour
# 176399  Disponibilité de protéines en quantité (g/pers...     g/personne/jour
# 176400  Disponibilité de matière grasse en quantité (g...     g/personne/jour
#
#         Valeur Symbole Description du Symbole
# 651      28.00       S  Données standardisées
# 652      29.00       S  Données standardisées
# 653       0.00       S  Données standardisées
# 654      57.00       S  Données standardisées
# 655       2.00       S  Données standardisées
# ...        ...     ...                    ...
# 176396   67.00       S  Données standardisées
# 176397    4.68      Fc        Donnée calculée
# 176398   16.00      Fc        Donnée calculée
# 176399    1.59      Fc        Donnée calculée
# 176400    0.99      Fc        Donnée calculée
#
# [2061 rows x 8 columns]

# %%
dd = {}
for i, ser in df.iterrows():

    k, v = ser["Élément"], ser["Unité"]
    dd[k] = v
dd
# Out:
# {'Production': 'Milliers de tonnes',
#  'Importations - Quantité': 'Milliers de tonnes',
#  'Variation de stock': 'Milliers de tonnes',
#  'Disponibilité intérieure': 'Milliers de tonnes',
#  'Pertes': 'Milliers de tonnes',
#  'Résidus': 'Milliers de tonnes',
#  'Nourriture': 'Milliers de tonnes',
#  'Disponibilité alimentaire en quantité (kg/personne/an)': 'kg',
#  'Disponibilité alimentaire (Kcal/personne/jour)': 'Kcal/personne/jour',
#  'Disponibilité de protéines en quantité (g/personne/jour)': 'g/personne/jour',
#  'Disponibilité de matière grasse en quantité (g/personne/jour)': 'g/personne/jour',
#  'Exportations - Quantité': 'Milliers de tonnes',
#  'Alimentation pour touristes': 'Milliers de tonnes',
#  'Traitement': 'Milliers de tonnes',
#  'Autres utilisations (non alimentaire)': 'Milliers de tonnes',
#  'Aliments pour animaux': 'Milliers de tonnes',
#  'Semences': 'Milliers de tonnes'}

# %%
cols = ["Code zone", "Zone", "Élément", "Valeur"]
cols
# Out:
# ['Code zone', 'Zone', 'Élément', 'Valeur']

# %%
df = df.loc[:, cols]
df
# Out:
#         Code zone         Zone  \
# 651             2  Afghanistan
# 652             2  Afghanistan
# 653             2  Afghanistan
# 654             2  Afghanistan
# 655             2  Afghanistan
# ...           ...          ...
# 176396        181     Zimbabwe
# 176397        181     Zimbabwe
# 176398        181     Zimbabwe
# 176399        181     Zimbabwe
# 176400        181     Zimbabwe
#
#                                                   Élément  Valeur
# 651                                            Production   28.00
# 652                               Importations - Quantité   29.00
# 653                                    Variation de stock    0.00
# 654                              Disponibilité intérieure   57.00
# 655                                                Pertes    2.00
# ...                                                   ...     ...
# 176396                                         Nourriture   67.00
# 176397  Disponibilité alimentaire en quantité (kg/pers...    4.68
# 176398     Disponibilité alimentaire (Kcal/personne/jour)   16.00
# 176399  Disponibilité de protéines en quantité (g/pers...    1.59
# 176400  Disponibilité de matière grasse en quantité (g...    0.99
#
# [2061 rows x 4 columns]

# %%
df = df.pivot(index=["Code zone", "Zone"], columns="Élément", values="Valeur")
df
# Out:
# Élément                Alimentation pour touristes  Aliments pour animaux  \
# Code zone Zone
# 1         Arménie                              NaN                    NaN
# 2         Afghanistan                          NaN                    NaN
# 3         Albanie                              NaN                    NaN
# 4         Algérie                              0.0                    NaN
# 7         Angola                               0.0                    NaN
# ...                                            ...                    ...
# 255       Belgique                             NaN                    NaN
# 256       Luxembourg                           NaN                    NaN
# 272       Serbie                               NaN                    NaN
# 273       Monténégro                           NaN                    NaN
# 276       Soudan                               0.0                    NaN
#
# Élément                Autres utilisations (non alimentaire)  \
# Code zone Zone
# 1         Arménie                                        NaN
# 2         Afghanistan                                    NaN
# 3         Albanie                                        NaN
# 4         Algérie                                        NaN
# 7         Angola                                         NaN
# ...                                                      ...
# 255       Belgique                                       NaN
# 256       Luxembourg                                     NaN
# 272       Serbie                                         NaN
# 273       Monténégro                                     NaN
# 276       Soudan                                         NaN
#
# Élément                Disponibilité alimentaire (Kcal/personne/jour)  \
# Code zone Zone
# 1         Arménie                                                54.0
# 2         Afghanistan                                             5.0
# 3         Albanie                                                85.0
# 4         Algérie                                                22.0
# 7         Angola                                                 35.0
# ...                                                               ...
# 255       Belgique                                               44.0
# 256       Luxembourg                                             69.0
# 272       Serbie                                                 35.0
# 273       Monténégro                                             55.0
# 276       Soudan                                                  5.0
#
# Élément                Disponibilité alimentaire en quantité (kg/personne/an)  \
# Code zone Zone
# 1         Arménie                                                  16.06
# 2         Afghanistan                                               1.53
# 3         Albanie                                                  16.36
# 4         Algérie                                                   6.38
# 7         Angola                                                   10.56
# ...                                                                  ...
# 255       Belgique                                                 12.65
# 256       Luxembourg                                               18.33
# 272       Serbie                                                   10.16
# 273       Monténégro                                               15.98
# 276       Soudan                                                    1.60
#
# Élément                Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Code zone Zone
# 1         Arménie                                                   3.39
# 2         Afghanistan                                               0.33
# 3         Albanie                                                   6.45
# 4         Algérie                                                   1.50
# 7         Angola                                                    2.22
# ...                                                                  ...
# 255       Belgique                                                  2.71
# 256       Luxembourg                                                4.28
# 272       Serbie                                                    2.24
# 273       Monténégro                                                3.37
# 276       Soudan                                                    0.34
#
# Élément                Disponibilité de protéines en quantité (g/personne/jour)  \
# Code zone Zone
# 1         Arménie                                                   5.44
# 2         Afghanistan                                               0.54
# 3         Albanie                                                   6.26
# 4         Algérie                                                   1.97
# 7         Angola                                                    3.60
# ...                                                                  ...
# 255       Belgique                                                  4.57
# 256       Luxembourg                                                7.19
# 272       Serbie                                                    3.50
# 273       Monténégro                                                5.79
# 276       Soudan                                                    0.54
#
# Élément                Disponibilité intérieure  Exportations - Quantité  \
# Code zone Zone
# 1         Arménie                          47.0                      0.0
# 2         Afghanistan                      57.0                      NaN
# 3         Albanie                          47.0                      0.0
# 4         Algérie                         277.0                      0.0
# 7         Angola                          319.0                      0.0
# ...                                         ...                      ...
# 255       Belgique                        152.0                    656.0
# 256       Luxembourg                       11.0                      1.0
# 272       Serbie                           90.0                      7.0
# 273       Monténégro                       10.0                      0.0
# 276       Soudan                           69.0                      NaN
#
# Élément                Importations - Quantité  Nourriture  Pertes  \
# Code zone Zone
# 1         Arménie                         35.0        47.0     0.0
# 2         Afghanistan                     29.0        55.0     2.0
# 3         Albanie                         38.0        47.0     NaN
# 4         Algérie                          2.0       264.0    13.0
# 7         Angola                         277.0       315.0     2.0
# ...                                        ...         ...     ...
# 255       Belgique                       338.0       144.0     0.0
# 256       Luxembourg                      11.0        11.0     NaN
# 272       Serbie                          12.0        90.0     NaN
# 273       Monténégro                       8.0        10.0     NaN
# 276       Soudan                           2.0        65.0     3.0
#
# Élément                Production  Résidus  Semences  Traitement  \
# Code zone Zone
# 1         Arménie            11.0      0.0       NaN         NaN
# 2         Afghanistan        28.0      0.0       NaN         NaN
# 3         Albanie            13.0      0.0       NaN         NaN
# 4         Algérie           275.0      0.0       NaN         NaN
# 7         Angola             42.0      0.0       NaN         2.0
# ...                           ...      ...       ...         ...
# 255       Belgique          463.0    -25.0       NaN        33.0
# 256       Luxembourg          0.0      0.0       NaN         NaN
# 272       Serbie             85.0     -0.0       NaN         NaN
# 273       Monténégro          4.0      0.0       NaN         NaN
# 276       Soudan             67.0      0.0       NaN         NaN
#
# Élément                Variation de stock
# Code zone Zone
# 1         Arménie                    -2.0
# 2         Afghanistan                 0.0
# 3         Albanie                     4.0
# 4         Algérie                     0.0
# 7         Angola                     -0.0
# ...                                   ...
# 255       Belgique                   -6.0
# 256       Luxembourg                  0.0
# 272       Serbie                      0.0
# 273       Monténégro                  1.0
# 276       Soudan                      0.0
#
# [172 rows x 17 columns]

# %%
df = df.reset_index()
df.columns.name = None
df
# Out:
#      Code zone         Zone  Alimentation pour touristes  \
# 0            1      Arménie                          NaN
# 1            2  Afghanistan                          NaN
# 2            3      Albanie                          NaN
# 3            4      Algérie                          0.0
# 4            7       Angola                          0.0
# ..         ...          ...                          ...
# 167        255     Belgique                          NaN
# 168        256   Luxembourg                          NaN
# 169        272       Serbie                          NaN
# 170        273   Monténégro                          NaN
# 171        276       Soudan                          0.0
#
#      Aliments pour animaux  Autres utilisations (non alimentaire)  \
# 0                      NaN                                    NaN
# 1                      NaN                                    NaN
# 2                      NaN                                    NaN
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN
# ..                     ...                                    ...
# 167                    NaN                                    NaN
# 168                    NaN                                    NaN
# 169                    NaN                                    NaN
# 170                    NaN                                    NaN
# 171                    NaN                                    NaN
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                              54.0
# 1                                               5.0
# 2                                              85.0
# 3                                              22.0
# 4                                              35.0
# ..                                              ...
# 167                                            44.0
# 168                                            69.0
# 169                                            35.0
# 170                                            55.0
# 171                                             5.0
#
#      Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                16.06
# 1                                                 1.53
# 2                                                16.36
# 3                                                 6.38
# 4                                                10.56
# ..                                                 ...
# 167                                              12.65
# 168                                              18.33
# 169                                              10.16
# 170                                              15.98
# 171                                               1.60
#
#      Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                 3.39
# 1                                                 0.33
# 2                                                 6.45
# 3                                                 1.50
# 4                                                 2.22
# ..                                                 ...
# 167                                               2.71
# 168                                               4.28
# 169                                               2.24
# 170                                               3.37
# 171                                               0.34
#
#      Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                 5.44
# 1                                                 0.54
# 2                                                 6.26
# 3                                                 1.97
# 4                                                 3.60
# ..                                                 ...
# 167                                               4.57
# 168                                               7.19
# 169                                               3.50
# 170                                               5.79
# 171                                               0.54
#
#      Disponibilité intérieure  Exportations - Quantité  \
# 0                        47.0                      0.0
# 1                        57.0                      NaN
# 2                        47.0                      0.0
# 3                       277.0                      0.0
# 4                       319.0                      0.0
# ..                        ...                      ...
# 167                     152.0                    656.0
# 168                      11.0                      1.0
# 169                      90.0                      7.0
# 170                      10.0                      0.0
# 171                      69.0                      NaN
#
#      Importations - Quantité  Nourriture  Pertes  Production  Résidus  \
# 0                       35.0        47.0     0.0        11.0      0.0
# 1                       29.0        55.0     2.0        28.0      0.0
# 2                       38.0        47.0     NaN        13.0      0.0
# 3                        2.0       264.0    13.0       275.0      0.0
# 4                      277.0       315.0     2.0        42.0      0.0
# ..                       ...         ...     ...         ...      ...
# 167                    338.0       144.0     0.0       463.0    -25.0
# 168                     11.0        11.0     NaN         0.0      0.0
# 169                     12.0        90.0     NaN        85.0     -0.0
# 170                      8.0        10.0     NaN         4.0      0.0
# 171                      2.0        65.0     3.0        67.0      0.0
#
#      Semences  Traitement  Variation de stock
# 0         NaN         NaN                -2.0
# 1         NaN         NaN                 0.0
# 2         NaN         NaN                 4.0
# 3         NaN         NaN                 0.0
# 4         NaN         2.0                -0.0
# ..        ...         ...                 ...
# 167       NaN        33.0                -6.0
# 168       NaN         NaN                 0.0
# 169       NaN         NaN                 0.0
# 170       NaN         NaN                 1.0
# 171       NaN         NaN                 0.0
#
# [172 rows x 19 columns]

# %%
nan_values = df.isna().mean().round(2)
nan_values
# Out:
# Code zone                                                        0.00
# Zone                                                             0.00
# Alimentation pour touristes                                      0.55
# Aliments pour animaux                                            0.99
# Autres utilisations (non alimentaire)                            0.80
# Disponibilité alimentaire (Kcal/personne/jour)                   0.00
# Disponibilité alimentaire en quantité (kg/personne/an)           0.00
# Disponibilité de matière grasse en quantité (g/personne/jour)    0.00
# Disponibilité de protéines en quantité (g/personne/jour)         0.00
# Disponibilité intérieure                                         0.01
# Exportations - Quantité                                          0.22
# Importations - Quantité                                          0.01
# Nourriture                                                       0.01
# Pertes                                                           0.61
# Production                                                       0.02
# Résidus                                                          0.05
# Semences                                                         0.99
# Traitement                                                       0.73
# Variation de stock                                               0.02
# dtype: float64

# %%
nan_values.sort_values(ascending=False)
# Out:
# Aliments pour animaux                                            0.99
# Semences                                                         0.99
# Autres utilisations (non alimentaire)                            0.80
# Traitement                                                       0.73
# Pertes                                                           0.61
# Alimentation pour touristes                                      0.55
# Exportations - Quantité                                          0.22
# Résidus                                                          0.05
# Variation de stock                                               0.02
# Production                                                       0.02
# Nourriture                                                       0.01
# Disponibilité intérieure                                         0.01
# Importations - Quantité                                          0.01
# Zone                                                             0.00
# Disponibilité de protéines en quantité (g/personne/jour)         0.00
# Disponibilité de matière grasse en quantité (g/personne/jour)    0.00
# Disponibilité alimentaire en quantité (kg/personne/an)           0.00
# Disponibilité alimentaire (Kcal/personne/jour)                   0.00
# Code zone                                                        0.00
# dtype: float64

# %%
cols = [
    "Code zone",
    "Zone",
    "Disponibilité intérieure",
    "Importations - Quantité",
    "Disponibilité de protéines en quantité (g/personne/jour)",
    "Disponibilité alimentaire (Kcal/personne/jour)",
    "Exportations - Quantité",
    "Résidus",
    "Variation de stock",
    "Production",
    "Nourriture",
]


df = df.loc[:, cols]
df
# Out:
#      Code zone         Zone  Disponibilité intérieure  \
# 0            1      Arménie                      47.0
# 1            2  Afghanistan                      57.0
# 2            3      Albanie                      47.0
# 3            4      Algérie                     277.0
# 4            7       Angola                     319.0
# ..         ...          ...                       ...
# 167        255     Belgique                     152.0
# 168        256   Luxembourg                      11.0
# 169        272       Serbie                      90.0
# 170        273   Monténégro                      10.0
# 171        276       Soudan                      69.0
#
#      Importations - Quantité  \
# 0                       35.0
# 1                       29.0
# 2                       38.0
# 3                        2.0
# 4                      277.0
# ..                       ...
# 167                    338.0
# 168                     11.0
# 169                     12.0
# 170                      8.0
# 171                      2.0
#
#      Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                 5.44
# 1                                                 0.54
# 2                                                 6.26
# 3                                                 1.97
# 4                                                 3.60
# ..                                                 ...
# 167                                               4.57
# 168                                               7.19
# 169                                               3.50
# 170                                               5.79
# 171                                               0.54
#
#      Disponibilité alimentaire (Kcal/personne/jour)  Exportations - Quantité  \
# 0                                              54.0                      0.0
# 1                                               5.0                      NaN
# 2                                              85.0                      0.0
# 3                                              22.0                      0.0
# 4                                              35.0                      0.0
# ..                                              ...                      ...
# 167                                            44.0                    656.0
# 168                                            69.0                      1.0
# 169                                            35.0                      7.0
# 170                                            55.0                      0.0
# 171                                             5.0                      NaN
#
#      Résidus  Variation de stock  Production  Nourriture
# 0        0.0                -2.0        11.0        47.0
# 1        0.0                 0.0        28.0        55.0
# 2        0.0                 4.0        13.0        47.0
# 3        0.0                 0.0       275.0       264.0
# 4        0.0                -0.0        42.0       315.0
# ..       ...                 ...         ...         ...
# 167    -25.0                -6.0       463.0       144.0
# 168      0.0                 0.0         0.0        11.0
# 169     -0.0                 0.0        85.0        90.0
# 170      0.0                 1.0         4.0        10.0
# 171      0.0                 0.0        67.0        65.0
#
# [172 rows x 11 columns]

# %%
df.isna().mean().round(2)
# Out:
# Code zone                                                   0.00
# Zone                                                        0.00
# Disponibilité intérieure                                    0.01
# Importations - Quantité                                     0.01
# Disponibilité de protéines en quantité (g/personne/jour)    0.00
# Disponibilité alimentaire (Kcal/personne/jour)              0.00
# Exportations - Quantité                                     0.22
# Résidus                                                     0.05
# Variation de stock                                          0.02
# Production                                                  0.02
# Nourriture                                                  0.01
# dtype: float64

# %%
df = df.fillna(0)   
df
# Out:
#      Code zone         Zone  Disponibilité intérieure  \
# 0            1      Arménie                      47.0
# 1            2  Afghanistan                      57.0
# 2            3      Albanie                      47.0
# 3            4      Algérie                     277.0
# 4            7       Angola                     319.0
# ..         ...          ...                       ...
# 167        255     Belgique                     152.0
# 168        256   Luxembourg                      11.0
# 169        272       Serbie                      90.0
# 170        273   Monténégro                      10.0
# 171        276       Soudan                      69.0
#
#      Importations - Quantité  \
# 0                       35.0
# 1                       29.0
# 2                       38.0
# 3                        2.0
# 4                      277.0
# ..                       ...
# 167                    338.0
# 168                     11.0
# 169                     12.0
# 170                      8.0
# 171                      2.0
#
#      Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                 5.44
# 1                                                 0.54
# 2                                                 6.26
# 3                                                 1.97
# 4                                                 3.60
# ..                                                 ...
# 167                                               4.57
# 168                                               7.19
# 169                                               3.50
# 170                                               5.79
# 171                                               0.54
#
#      Disponibilité alimentaire (Kcal/personne/jour)  Exportations - Quantité  \
# 0                                              54.0                      0.0
# 1                                               5.0                      0.0
# 2                                              85.0                      0.0
# 3                                              22.0                      0.0
# 4                                              35.0                      0.0
# ..                                              ...                      ...
# 167                                            44.0                    656.0
# 168                                            69.0                      1.0
# 169                                            35.0                      7.0
# 170                                            55.0                      0.0
# 171                                             5.0                      0.0
#
#      Résidus  Variation de stock  Production  Nourriture
# 0        0.0                -2.0        11.0        47.0
# 1        0.0                 0.0        28.0        55.0
# 2        0.0                 4.0        13.0        47.0
# 3        0.0                 0.0       275.0       264.0
# 4        0.0                -0.0        42.0       315.0
# ..       ...                 ...         ...         ...
# 167    -25.0                -6.0       463.0       144.0
# 168      0.0                 0.0         0.0        11.0
# 169     -0.0                 0.0        85.0        90.0
# 170      0.0                 1.0         4.0        10.0
# 171      0.0                 0.0        67.0        65.0
#
# [172 rows x 11 columns]

# %%
df.isna().mean().round(2)
# Out:
# Code zone                                                   0.0
# Zone                                                        0.0
# Disponibilité intérieure                                    0.0
# Importations - Quantité                                     0.0
# Disponibilité de protéines en quantité (g/personne/jour)    0.0
# Disponibilité alimentaire (Kcal/personne/jour)              0.0
# Exportations - Quantité                                     0.0
# Résidus                                                     0.0
# Variation de stock                                          0.0
# Production                                                  0.0
# Nourriture                                                  0.0
# dtype: float64

# %%
# Out:
#                                                     Disponibilité intérieure  \
# Disponibilité intérieure                                            1.000000
# Importations - Quantité                                             0.263670
# Disponibilité de protéines en quantité (g/perso...                  0.177511
# Disponibilité alimentaire (Kcal/personne/jour)                      0.210961
# Exportations - Quantité                                             0.685745
# Résidus                                                             0.000092
# Variation de stock                                                  0.056146
# Production                                                          0.988052
# Nourriture                                                          0.998721
#
#                                                     Importations - Quantité  \
# Disponibilité intérieure                                           0.263670
# Importations - Quantité                                            1.000000
# Disponibilité de protéines en quantité (g/perso...                 0.219068
# Disponibilité alimentaire (Kcal/personne/jour)                     0.175009
# Exportations - Quantité                                            0.160605
# Résidus                                                           -0.409761
# Variation de stock                                                 0.303199
# Production                                                         0.195613
# Nourriture                                                         0.263042
#
#                                                     Disponibilité de protéines en quantité (g/personne/jour)  \
# Disponibilité intérieure                                                                     0.177511
# Importations - Quantité                                                                      0.219068
# Disponibilité de protéines en quantité (g/perso...                                           1.000000
# Disponibilité alimentaire (Kcal/personne/jour)                                               0.972563
# Exportations - Quantité                                                                      0.246483
# Résidus                                                                                     -0.176593
# Variation de stock                                                                           0.067184
# Production                                                                                   0.187281
# Nourriture                                                                                   0.182509
#
#                                                     Disponibilité alimentaire (Kcal/personne/jour)  \
# Disponibilité intérieure                                                                  0.210961
# Importations - Quantité                                                                   0.175009
# Disponibilité de protéines en quantité (g/perso...                                        0.972563
# Disponibilité alimentaire (Kcal/personne/jour)                                            1.000000
# Exportations - Quantité                                                                   0.265371
# Résidus                                                                                  -0.122551
# Variation de stock                                                                        0.057782
# Production                                                                                0.223209
# Nourriture                                                                                0.216412
#
#                                                     Exportations - Quantité  \
# Disponibilité intérieure                                           0.685745
# Importations - Quantité                                            0.160605
# Disponibilité de protéines en quantité (g/perso...                 0.246483
# Disponibilité alimentaire (Kcal/personne/jour)                     0.265371
# Exportations - Quantité                                            1.000000
# Résidus                                                           -0.281196
# Variation de stock                                                 0.056659
# Production                                                         0.777650
# Nourriture                                                         0.698049
#
#                                                      Résidus  \
# Disponibilité intérieure                            0.000092
# Importations - Quantité                            -0.409761
# Disponibilité de protéines en quantité (g/perso... -0.176593
# Disponibilité alimentaire (Kcal/personne/jour)     -0.122551
# Exportations - Quantité                            -0.281196
# Résidus                                             1.000000
# Variation de stock                                 -0.004240
# Production                                         -0.021324
# Nourriture                                         -0.003712
#
#                                                     Variation de stock  \
# Disponibilité intérieure                                      0.056146
# Importations - Quantité                                       0.303199
# Disponibilité de protéines en quantité (g/perso...            0.067184
# Disponibilité alimentaire (Kcal/personne/jour)                0.057782
# Exportations - Quantité                                       0.056659
# Résidus                                                      -0.004240
# Variation de stock                                            1.000000
# Production                                                    0.067271
# Nourriture                                                    0.059630
#
#                                                     Production  Nourriture
# Disponibilité intérieure                              0.988052    0.998721
# Importations - Quantité                               0.195613    0.263042
# Disponibilité de protéines en quantité (g/perso...    0.187281    0.182509
# Disponibilité alimentaire (Kcal/personne/jour)        0.223209    0.216412
# Exportations - Quantité                               0.777650    0.698049
# Résidus                                              -0.021324   -0.003712
# Variation de stock                                    0.067271    0.059630
# Production                                            1.000000    0.989357
# Nourriture                                            0.989357    1.000000

# %%
cols = ["code_zone", "zone", "dispo_int", "import", "dispo_prot", "dispo_alim", "export", "residus", "var_stock", "prod", "nourriture"]
df.columns = cols
df
# Out:
#      code_zone         zone  dispo_int  import  dispo_prot  dispo_alim  \
# 0            1      Arménie       47.0    35.0        5.44        54.0
# 1            2  Afghanistan       57.0    29.0        0.54         5.0
# 2            3      Albanie       47.0    38.0        6.26        85.0
# 3            4      Algérie      277.0     2.0        1.97        22.0
# 4            7       Angola      319.0   277.0        3.60        35.0
# ..         ...          ...        ...     ...         ...         ...
# 167        255     Belgique      152.0   338.0        4.57        44.0
# 168        256   Luxembourg       11.0    11.0        7.19        69.0
# 169        272       Serbie       90.0    12.0        3.50        35.0
# 170        273   Monténégro       10.0     8.0        5.79        55.0
# 171        276       Soudan       69.0     2.0        0.54         5.0
#
#      export  residus  var_stock   prod  nourriture
# 0       0.0      0.0       -2.0   11.0        47.0
# 1       0.0      0.0        0.0   28.0        55.0
# 2       0.0      0.0        4.0   13.0        47.0
# 3       0.0      0.0        0.0  275.0       264.0
# 4       0.0      0.0       -0.0   42.0       315.0
# ..      ...      ...        ...    ...         ...
# 167   656.0    -25.0       -6.0  463.0       144.0
# 168     1.0      0.0        0.0    0.0        11.0
# 169     7.0     -0.0        0.0   85.0        90.0
# 170     0.0      0.0        1.0    4.0        10.0
# 171     0.0      0.0        0.0   67.0        65.0
#
# [172 rows x 11 columns]

# %%
corr = df.select_dtypes(float).corr()
corr
# Out:
#             dispo_int    import  dispo_prot  dispo_alim    export   residus  \
# dispo_int    1.000000  0.263670    0.177511    0.210961  0.685745  0.000092
# import       0.263670  1.000000    0.219068    0.175009  0.160605 -0.409761
# dispo_prot   0.177511  0.219068    1.000000    0.972563  0.246483 -0.176593
# dispo_alim   0.210961  0.175009    0.972563    1.000000  0.265371 -0.122551
# export       0.685745  0.160605    0.246483    0.265371  1.000000 -0.281196
# residus      0.000092 -0.409761   -0.176593   -0.122551 -0.281196  1.000000
# var_stock    0.056146  0.303199    0.067184    0.057782  0.056659 -0.004240
# prod         0.988052  0.195613    0.187281    0.223209  0.777650 -0.021324
# nourriture   0.998721  0.263042    0.182509    0.216412  0.698049 -0.003712
#
#             var_stock      prod  nourriture
# dispo_int    0.056146  0.988052    0.998721
# import       0.303199  0.195613    0.263042
# dispo_prot   0.067184  0.187281    0.182509
# dispo_alim   0.057782  0.223209    0.216412
# export       0.056659  0.777650    0.698049
# residus     -0.004240 -0.021324   -0.003712
# var_stock    1.000000  0.067271    0.059630
# prod         0.067271  1.000000    0.989357
# nourriture   0.059630  0.989357    1.000000

# %%
import numpy as np
import seaborn as sns   

mask = np.triu(corr)
sns.heatmap(corr, annot=True, mask=mask, vmax=1, vmin=-1, cmap="coolwarm", fmt=".2f")
# Out:
# <Axes: >

# %%
pop = pd.read_csv("pop.csv")
pop
# Out:
#      Code Domaine                       Domaine  Code zone         Zone  \
# 0              OA  Séries temporelles annuelles          2  Afghanistan
# 1              OA  Séries temporelles annuelles          2  Afghanistan
# 2              OA  Séries temporelles annuelles          2  Afghanistan
# 3              OA  Séries temporelles annuelles          2  Afghanistan
# 4              OA  Séries temporelles annuelles          2  Afghanistan
# ...           ...                           ...        ...          ...
# 4406           OA  Séries temporelles annuelles        181     Zimbabwe
# 4407           OA  Séries temporelles annuelles        181     Zimbabwe
# 4408           OA  Séries temporelles annuelles        181     Zimbabwe
# 4409           OA  Séries temporelles annuelles        181     Zimbabwe
# 4410           OA  Séries temporelles annuelles        181     Zimbabwe
#
#       Code Élément            Élément  Code Produit                 Produit  \
# 0              511  Population totale          3010  Population-Estimations
# 1              511  Population totale          3010  Population-Estimations
# 2              511  Population totale          3010  Population-Estimations
# 3              511  Population totale          3010  Population-Estimations
# 4              511  Population totale          3010  Population-Estimations
# ...            ...                ...           ...                     ...
# 4406           511  Population totale          3010  Population-Estimations
# 4407           511  Population totale          3010  Population-Estimations
# 4408           511  Population totale          3010  Population-Estimations
# 4409           511  Population totale          3010  Population-Estimations
# 4410           511  Population totale          3010  Population-Estimations
#
#       Code année  Année           Unité     Valeur Symbole  \
# 0           2000   2000  1000 personnes  20779.953       X
# 1           2001   2001  1000 personnes  21606.988       X
# 2           2002   2002  1000 personnes  22600.770       X
# 3           2003   2003  1000 personnes  23680.871       X
# 4           2004   2004  1000 personnes  24726.684       X
# ...          ...    ...             ...        ...     ...
# 4406        2014   2014  1000 personnes  13586.707       X
# 4407        2015   2015  1000 personnes  13814.629       X
# 4408        2016   2016  1000 personnes  14030.331       X
# 4409        2017   2017  1000 personnes  14236.595       X
# 4410        2018   2018  1000 personnes  14438.802       X
#
#              Description du Symbole Note
# 0     Sources internationales sûres  NaN
# 1     Sources internationales sûres  NaN
# 2     Sources internationales sûres  NaN
# 3     Sources internationales sûres  NaN
# 4     Sources internationales sûres  NaN
# ...                             ...  ...
# 4406  Sources internationales sûres  NaN
# 4407  Sources internationales sûres  NaN
# 4408  Sources internationales sûres  NaN
# 4409  Sources internationales sûres  NaN
# 4410  Sources internationales sûres  NaN
#
# [4411 rows x 15 columns]

# %%
pop = pop.pivot(index=["Code zone", "Zone"], columns="Année", values="Valeur")
pop.reset_index(inplace=True)
pop.columns.name = None
pop
# Out:
#      Code zone                                 Zone       2000       2001  \
# 0            1                              Arménie   3069.591   3050.687
# 1            2                          Afghanistan  20779.953  21606.988
# 2            3                              Albanie   3129.243   3129.704
# 3            4                              Algérie  31042.235  31451.514
# 4            5                    Samoa américaines     57.821     58.494
# ..         ...                                  ...        ...        ...
# 233        279                              Curaçao        NaN        NaN
# 234        280  Sint Maarten  (partie néerlandaise)        NaN        NaN
# 235        281      Saint-Martin (partie française)        NaN        NaN
# 236        282                     Saint-Barthélemy        NaN        NaN
# 237        299                            Palestine   3224.003   3309.910
#
#           2002       2003       2004       2005       2006       2007  ...  \
# 0     3033.978   3017.932   3000.720   2981.269   2958.307   2932.618  ...
# 1    22600.770  23680.871  24726.684  25654.277  26433.049  27100.536  ...
# 2     3126.187   3118.023   3104.892   3086.810   3063.021   3033.998  ...
# 3    31855.109  32264.157  32692.163  33149.724  33641.002  34166.972  ...
# 4       59.080     59.504     59.681     59.562     59.107     58.365  ...
# ..         ...        ...        ...        ...        ...        ...  ...
# 233        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 234        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 235        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 236        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 237   3380.164   3441.865   3505.323   3577.961   3662.422   3756.460  ...
#
#           2009       2010       2011       2012       2013       2014  \
# 0     2888.092   2877.319   2876.538   2884.234   2897.588   2912.409
# 1    28394.813  29185.507  30117.413  31161.376  32269.589  33370.794
# 2     2973.048   2948.023   2928.592   2914.096   2903.790   2896.305
# 3    35333.881  35977.455  36661.445  37383.895  38140.133  38923.692
# 4       56.683     56.079     55.759     55.667     55.713     55.791
# ..         ...        ...        ...        ...        ...        ...
# 233        NaN        NaN    152.315    154.817    156.794    158.422
# 234        NaN        NaN     35.058     36.241     37.583     38.876
# 235        NaN        NaN     37.446     37.009     36.453     36.015
# 236        NaN        NaN      9.343      9.439      9.537      9.623
# 237   3957.670   4055.631   4149.649   4241.573   4333.523   4428.639
#
#           2015       2016       2017       2018
# 0     2925.553   2936.143   2944.791   2951.745
# 1    34413.603  35383.032  36296.113  37171.921
# 2     2890.513   2886.438   2884.169   2882.740
# 3    39728.025  40551.392  41389.189  42228.408
# 4       55.812     55.741     55.620     55.465
# ..         ...        ...        ...        ...
# 233    159.847    161.052    161.997    162.752
# 234     39.968     40.808     41.444     41.940
# 235     35.858     36.065     36.560     37.264
# 236      9.693      9.748      9.784      9.816
# 237   4529.166   4635.654   4747.227   4862.979
#
# [238 rows x 21 columns]

# %%
pop.isna().mean().round(2)
# Out:
# Code zone    0.00
# Zone         0.00
# 2000         0.04
# 2001         0.04
# 2002         0.04
# 2003         0.04
# 2004         0.04
# 2005         0.04
# 2006         0.03
# 2007         0.03
# 2008         0.03
# 2009         0.03
# 2010         0.03
# 2011         0.01
# 2012         0.01
# 2013         0.01
# 2014         0.01
# 2015         0.01
# 2016         0.01
# 2017         0.01
# 2018         0.01
# dtype: float64

# %%
pop.columns
# Out:
# Index(['Code zone',      'Zone',        2000,        2001,        2002,
#               2003,        2004,        2005,        2006,        2007,
#               2008,        2009,        2010,        2011,        2012,
#               2013,        2014,        2015,        2016,        2017,
#               2018],
#       dtype='object')

# %%
cols = ['Code zone',      'Zone',        2017,] 
pop = pop.loc[:, cols]
pop
# Out:
#      Code zone                                 Zone       2017
# 0            1                              Arménie   2944.791
# 1            2                          Afghanistan  36296.113
# 2            3                              Albanie   2884.169
# 3            4                              Algérie  41389.189
# 4            5                    Samoa américaines     55.620
# ..         ...                                  ...        ...
# 233        279                              Curaçao    161.997
# 234        280  Sint Maarten  (partie néerlandaise)     41.444
# 235        281      Saint-Martin (partie française)     36.560
# 236        282                     Saint-Barthélemy      9.784
# 237        299                            Palestine   4747.227
#
# [238 rows x 3 columns]

# %%
cols = [
    "code_zone",
    "zone",
    "population",
]
pop.columns = cols
pop
# Out:
#      code_zone                                 zone  population
# 0            1                              Arménie    2944.791
# 1            2                          Afghanistan   36296.113
# 2            3                              Albanie    2884.169
# 3            4                              Algérie   41389.189
# 4            5                    Samoa américaines      55.620
# ..         ...                                  ...         ...
# 233        279                              Curaçao     161.997
# 234        280  Sint Maarten  (partie néerlandaise)      41.444
# 235        281      Saint-Martin (partie française)      36.560
# 236        282                     Saint-Barthélemy       9.784
# 237        299                            Palestine    4747.227
#
# [238 rows x 3 columns]

# %%
pop = pop.loc[:, ["code_zone", "population"]]
pop
# Out:
#      code_zone  population
# 0            1    2944.791
# 1            2   36296.113
# 2            3    2884.169
# 3            4   41389.189
# 4            5      55.620
# ..         ...         ...
# 233        279     161.997
# 234        280      41.444
# 235        281      36.560
# 236        282       9.784
# 237        299    4747.227
#
# [238 rows x 2 columns]

# %%
df.merge(pop, on="code_zone", how="left")
df = df.merge(pop, on="code_zone", how="left")
df
# Out:
#      code_zone         zone  dispo_int  import  dispo_prot  dispo_alim  \
# 0            1      Arménie       47.0    35.0        5.44        54.0
# 1            2  Afghanistan       57.0    29.0        0.54         5.0
# 2            3      Albanie       47.0    38.0        6.26        85.0
# 3            4      Algérie      277.0     2.0        1.97        22.0
# 4            7       Angola      319.0   277.0        3.60        35.0
# ..         ...          ...        ...     ...         ...         ...
# 167        255     Belgique      152.0   338.0        4.57        44.0
# 168        256   Luxembourg       11.0    11.0        7.19        69.0
# 169        272       Serbie       90.0    12.0        3.50        35.0
# 170        273   Monténégro       10.0     8.0        5.79        55.0
# 171        276       Soudan       69.0     2.0        0.54         5.0
#
#      export  residus  var_stock   prod  nourriture  population
# 0       0.0      0.0       -2.0   11.0        47.0    2944.791
# 1       0.0      0.0        0.0   28.0        55.0   36296.113
# 2       0.0      0.0        4.0   13.0        47.0    2884.169
# 3       0.0      0.0        0.0  275.0       264.0   41389.189
# 4       0.0      0.0       -0.0   42.0       315.0   29816.766
# ..      ...      ...        ...    ...         ...         ...
# 167   656.0    -25.0       -6.0  463.0       144.0   11419.748
# 168     1.0      0.0        0.0    0.0        11.0     591.910
# 169     7.0     -0.0        0.0   85.0        90.0    8829.628
# 170     0.0      0.0        1.0    4.0        10.0     627.563
# 171     0.0      0.0        0.0   67.0        65.0   40813.397
#
# [172 rows x 12 columns]

# %%
df.to_csv("chicken.csv", index=False)
